# %% [markdown]
# shreya soddi

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv 
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# ORIGINAL IMAGE

# %%
original_image= cv.imread('/content/drive/MyDrive/Flower-Backgrounds.webp')
cv2_imshow(original_image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x340 at 0x7F83364ACA30>

# %% [markdown]
# GRAYSCALE IMAGE

# %%
gray_image = cv.cvtColor(original_image, cv.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=600x340 at 0x7F83364ACA30>

# %% [markdown]
# INVERTED IMAGE

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=600x340 at 0x7F833645C0A0>

# %% [markdown]
# BLURRED IMAGE

# %%
blurred_image = cv.GaussianBlur(inverted_image, (21,21), 0)
cv2_imshow(blurred_image)
# Out:
# <PIL.Image.Image image mode=L size=600x340 at 0x7F833645CC10>

# %% [markdown]
# FINAL IMAGE

# %%
def dodgeV2(x, y):
    return cv.divide(x, 255- y, scale = 256)

# %%
final_image = dodgeV2(gray_image, blurred_image)
cv2_imshow(final_image)
# Out:
# <PIL.Image.Image image mode=L size=600x340 at 0x7F833645CF40>

# %% [markdown]
# # **Final Output**

# %%
original_image= cv.imread('/content/drive/MyDrive/Flower-Backgrounds.webp')
cv2_imshow(original_image)

final_image = dodgeV2(gray_image, blurred_image)
cv2_imshow(final_image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x340 at 0x7F833645C1F0>
# <PIL.Image.Image image mode=L size=600x340 at 0x7F83364ACD30>
